# %% [markdown]
# # General information

# %% [markdown]
# <i>'No BS, just essential pandas!'</i>
#
# Cheat sheet to data wrangling with Python pandas. The aim is to cover essential tips and tricks for data work flow. Each topic is featured with a minimal working example. The cheat sheet is work in progress, meaning that all suggestions for improvements are welcome!
#
# Note: Section numbering and links visible in the table of contents unfortunately do not work in the code cells due to restrictions in Github Jupyter notebook support. Use browser search field instead to locate desired headline.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#General-information" data-toc-modified-id="General-information-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>General information</a></span></li><li><span><a href="#Input/output-data" data-toc-modified-id="Input/output-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Input/output data</a></span><ul class="toc-item"><li><span><a href="#Excel-files" data-toc-modified-id="Excel-files-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Excel files</a></span><ul class="toc-item"><li><span><a href="#Import-Excel-file" data-toc-modified-id="Import-Excel-file-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Import Excel file</a></span></li><li><span><a href="#Export-Excel-file" data-toc-modified-id="Export-Excel-file-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Export Excel file</a></span><ul class="toc-item"><li><span><a href="#Quick-and-dirty" data-toc-modified-id="Quick-and-dirty-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Quick and dirty</a></span></li><li><span><a href="#More-complete" data-toc-modified-id="More-complete-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>More complete</a></span></li></ul></li></ul></li><li><span><a href="#SQL" data-toc-modified-id="SQL-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>SQL</a></span><ul class="toc-item"><li><span><a href="#Import-SQL-table" data-toc-modified-id="Import-SQL-table-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Import SQL table</a></span></li></ul></li></ul></li><li><span><a href="#Basic-DataFrame-operations" data-toc-modified-id="Basic-DataFrame-operations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Basic DataFrame operations</a></span><ul class="toc-item"><li><span><a href="#DataFrame-initialization" data-toc-modified-id="DataFrame-initialization-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>DataFrame initialization</a></span></li><li><span><a href="#Modifying-DataFrame" data-toc-modified-id="Modifying-DataFrame-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Modifying DataFrame</a></span><ul class="toc-item"><li><span><a href="#Renaming-columns" data-toc-modified-id="Renaming-columns-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Renaming columns</a></span></li><li><span><a href="#Sort-DataFrame-in-custom-column-order" data-toc-modified-id="Sort-DataFrame-in-custom-column-order-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Sort DataFrame in custom column order</a></span></li><li><span><a href="#Sort-DataFrame-in-custom-row-order" data-toc-modified-id="Sort-DataFrame-in-custom-row-order-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Sort DataFrame in custom row order</a></span></li><li><span><a href="#Changing-data-types" data-toc-modified-id="Changing-data-types-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Changing data types</a></span></li><li><span><a href="#Add-row-to-DataFrame" data-toc-modified-id="Add-row-to-DataFrame-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Add row to DataFrame</a></span></li><li><span><a href="#Add-column-to-DataFrame" data-toc-modified-id="Add-column-to-DataFrame-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Add column to DataFrame</a></span></li><li><span><a href="#Dropping-from-DataFrame" data-toc-modified-id="Dropping-from-DataFrame-3.2.7"><span class="toc-item-num">3.2.7&nbsp;&nbsp;</span>Dropping from DataFrame</a></span></li><li><span><a href="#Altering-DataFrame-values-by-broadcasting" data-toc-modified-id="Altering-DataFrame-values-by-broadcasting-3.2.8"><span class="toc-item-num">3.2.8&nbsp;&nbsp;</span>Altering DataFrame values by broadcasting</a></span></li><li><span><a href="#Concatenate-two-columns-into-one" data-toc-modified-id="Concatenate-two-columns-into-one-3.2.9"><span class="toc-item-num">3.2.9&nbsp;&nbsp;</span>Concatenate two columns into one</a></span></li></ul></li><li><span><a href="#Slicing-data-frame" data-toc-modified-id="Slicing-data-frame-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Slicing data frame</a></span><ul class="toc-item"><li><span><a href="#Basic-sclicing" data-toc-modified-id="Basic-sclicing-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Basic sclicing</a></span></li><li><span><a href="#Conditional-slicing/indexing-(boolean-masking)" data-toc-modified-id="Conditional-slicing/indexing-(boolean-masking)-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Conditional slicing/indexing (boolean masking)</a></span></li><li><span><a href="#Slicing-based-on-partial-string-match-in-column" data-toc-modified-id="Slicing-based-on-partial-string-match-in-column-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Slicing based on partial string match in column</a></span></li></ul></li><li><span><a href="#Iterating-over-DataFrame" data-toc-modified-id="Iterating-over-DataFrame-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Iterating over DataFrame</a></span></li><li><span><a href="#About-chain-indexing" data-toc-modified-id="About-chain-indexing-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>About chain indexing</a></span></li><li><span><a href="#Method-chaining" data-toc-modified-id="Method-chaining-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Method chaining</a></span></li><li><span><a href="#Data-types-and-scales" data-toc-modified-id="Data-types-and-scales-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Data types and scales</a></span></li></ul></li><li><span><a href="#Hierarchical-indexing-(MultiIndex)" data-toc-modified-id="Hierarchical-indexing-(MultiIndex)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Hierarchical indexing (MultiIndex)</a></span><ul class="toc-item"><li><span><a href="#Initialize-DataFrame-with-hierarchical-indexing" data-toc-modified-id="Initialize-DataFrame-with-hierarchical-indexing-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Initialize DataFrame with hierarchical indexing</a></span></li><li><span><a href="#Modifying-MultiIndex-DataFrame" data-toc-modified-id="Modifying-MultiIndex-DataFrame-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Modifying MultiIndex DataFrame</a></span><ul class="toc-item"><li><span><a href="#Add-second-index-to-existing-DataFrame" data-toc-modified-id="Add-second-index-to-existing-DataFrame-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Add second index to existing DataFrame</a></span></li><li><span><a href="#Add-new-column-to-existing-MultiIndex-DataFrame" data-toc-modified-id="Add-new-column-to-existing-MultiIndex-DataFrame-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Add new column to existing MultiIndex DataFrame</a></span></li><li><span><a href="#Get-different-MultiIndex-levels" data-toc-modified-id="Get-different-MultiIndex-levels-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Get different MultiIndex levels</a></span></li></ul></li><li><span><a href="#Quering-MultiIndex-DataFrames" data-toc-modified-id="Quering-MultiIndex-DataFrames-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Quering MultiIndex DataFrames</a></span></li></ul></li><li><span><a href="#Data-wrangling-tricks" data-toc-modified-id="Data-wrangling-tricks-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data wrangling tricks</a></span><ul class="toc-item"><li><span><a href="#Mappings-for-column-values" data-toc-modified-id="Mappings-for-column-values-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Mappings for column values</a></span><ul class="toc-item"><li><span><a href="#One-to-one-mappings" data-toc-modified-id="One-to-one-mappings-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>One-to-one mappings</a></span><ul class="toc-item"><li><span><a href="#Map-from-dict" data-toc-modified-id="Map-from-dict-5.1.1.1"><span class="toc-item-num">5.1.1.1&nbsp;&nbsp;</span>Map from dict</a></span></li><li><span><a href="#Assign-unique-identifier-to-column-values" data-toc-modified-id="Assign-unique-identifier-to-column-values-5.1.1.2"><span class="toc-item-num">5.1.1.2&nbsp;&nbsp;</span>Assign unique identifier to column values</a></span></li><li><span><a href="#Map-column-string-values-to-lowercase" data-toc-modified-id="Map-column-string-values-to-lowercase-5.1.1.3"><span class="toc-item-num">5.1.1.3&nbsp;&nbsp;</span>Map column string values to lowercase</a></span></li><li><span><a href="#Using-regex-with-map" data-toc-modified-id="Using-regex-with-map-5.1.1.4"><span class="toc-item-num">5.1.1.4&nbsp;&nbsp;</span>Using regex with map</a></span></li></ul></li><li><span><a href="#Map-values-to-ranges/groups" data-toc-modified-id="Map-values-to-ranges/groups-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Map values to ranges/groups</a></span></li><li><span><a href="#Categorical-variable-to-dummy-columns" data-toc-modified-id="Categorical-variable-to-dummy-columns-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Categorical variable to dummy columns</a></span></li><li><span><a href="#Map-column-string-values-to-lowercase" data-toc-modified-id="Map-column-string-values-to-lowercase-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Map column string values to lowercase</a></span></li></ul></li><li><span><a href="#Change-between-long/wide-format" data-toc-modified-id="Change-between-long/wide-format-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Change between long/wide format</a></span><ul class="toc-item"><li><span><a href="#Wide-to-long" data-toc-modified-id="Wide-to-long-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Wide to long</a></span></li><li><span><a href="#Long-to-wide" data-toc-modified-id="Long-to-wide-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Long to wide</a></span></li></ul></li><li><span><a href="#Database-like-joins" data-toc-modified-id="Database-like-joins-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Database-like joins</a></span></li><li><span><a href="#Aggregating-infromation-in-DataFrame" data-toc-modified-id="Aggregating-infromation-in-DataFrame-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Aggregating infromation in DataFrame</a></span><ul class="toc-item"><li><span><a href="#Simple-means,-medians-etc." data-toc-modified-id="Simple-means,-medians-etc.-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Simple means, medians etc.</a></span></li><li><span><a href="#'Group-by'-in-various-forms" data-toc-modified-id="'Group-by'-in-various-forms-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>'Group by' in various forms</a></span></li><li><span><a href="#Agg-method" data-toc-modified-id="Agg-method-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Agg method</a></span></li><li><span><a href="#Pivot-table" data-toc-modified-id="Pivot-table-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>Pivot table</a></span></li></ul></li></ul></li><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data cleaning</a></span><ul class="toc-item"><li><span><a href="#Replace-all-non-numerical-values-with-NaN" data-toc-modified-id="Replace-all-non-numerical-values-with-NaN-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Replace all non-numerical values with NaN</a></span></li><li><span><a href="#Find-NaN-values-from-DataFrame" data-toc-modified-id="Find-NaN-values-from-DataFrame-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Find NaN values from DataFrame</a></span></li><li><span><a href="#Clean-NaN-values" data-toc-modified-id="Clean-NaN-values-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Clean NaN values</a></span></li><li><span><a href="#Drop-rows/columns-with-NaN-values" data-toc-modified-id="Drop-rows/columns-with-NaN-values-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Drop rows/columns with NaN values</a></span></li></ul></li><li><span><a href="#Working-with-time-and-dates" data-toc-modified-id="Working-with-time-and-dates-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Working with time and dates</a></span><ul class="toc-item"><li><span><a href="#Time-and-date-data-types" data-toc-modified-id="Time-and-date-data-types-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Time and date data types</a></span></li><li><span><a href="#Time-series-tricks" data-toc-modified-id="Time-series-tricks-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Time series tricks</a></span><ul class="toc-item"><li><span><a href="#Basic-operations" data-toc-modified-id="Basic-operations-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Basic operations</a></span></li><li><span><a href="#Get-mean-value-per-day-over-multiple-years" data-toc-modified-id="Get-mean-value-per-day-over-multiple-years-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Get mean value per day over multiple years</a></span></li></ul></li></ul></li></ul></div>

# %%
############################################################
# Run this cell!
# Dependencies, auxiliary functions etc.
############################################################
import pandas as pd
import numpy as np
import datetime
from IPython.display import display_html
from IPython.display import display
import datetime
import random

def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    html_str = html_str.replace('table','table style="display:inline; border:0px"')          
    display_html(html_str,raw=True)

# %% [markdown]
# # Input/output data

# %% [markdown]
# ## Excel files

# %% [markdown]
# ### Import Excel file

# %%
# Example applies to Windows paths
import os
path = r'C:\myfolder'
file = 'myfile.xlsx'
df = pd.read_excel(os.path.join(path,file)
                   ,sheetname = 'Sheet1'
                   ,skiprows = 16
                   ,parse_cols = ("A,C:F")
                   ,header = None
                   ,index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9d64bc7bbf13> in <module>()
#       8                    ,parse_cols = ("A,C:F")
#       9                    ,header = None
# ---> 10                    ,index_col = 0)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, engine, squeeze, **kwds)
#     168     """
#     169     if not isinstance(io, ExcelFile):
# --> 170         io = ExcelFile(io, engine=engine)
#     171
#     172     return io._parse_excel(
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     225             self.book = xlrd.open_workbook(file_contents=data)
#     226         elif isinstance(io, compat.string_types):
# --> 227             self.book = xlrd.open_workbook(io)
#     228         else:
#     229             raise ValueError('Must explicitly set engine if not passing in'
#
# C:\Program Files\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\myfolder\\myfile.xlsx'

# %% [markdown]
# ### Export Excel file

# %% [markdown]
# #### Quick and dirty

# %%
# Example applies to Windows paths
import os
path = r'C:\myfolder'
file = 'myfile.xlsx'
writer = pd.ExcelWriter(os.path.join(path,file))
df.to_excel(writer, 'Sheet1', header = True)
writer.save()

# %% [markdown]
# #### More complete

# %%
# Styling:
# http://pbpython.com/improve-pandas-excel-output.html
from openpyxl import load_workbook
book = load_workbook(os.path.join(path,file))
writer = pd.ExcelWriter('results.xlsx', engine = 'openpyxl')
writer.book = book

#writer.sheets = dict((ws.title, ws) for ws in book.worksheets) # get sheet names for writer

book.remove_sheet(book.get_sheet_by_name('Sheet1'))

df.to_excel(writer, "Sheet1", header = True, startrow = 1, startcol = 1)
df.to_excel(writer, "Sheet1", header = True, startrow = 1, startcol = 19)
writer.save()

# %% [markdown]
# ## SQL

# %% [markdown]
# ### Import SQL table

# %%
cnxn = pyodbc.connect("Driver = {SQL Server};"
                      "Server = {server_name};"
                      "Database = dbo_name;"
                      "Trusted_Connection = yes;")
cursor = cnxn.cursor()
sql = "SELECT *" \
      "FROM dbo.table"
df = psql.read_sql_query(sql, cnxn)
cnxn.close()

# %% [markdown]
# # Basic DataFrame operations

# %% [markdown]
# ## DataFrame initialization

# %%
# Initialize DataFrame with dummy data and custom indices
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uu'])
display(df)
# Out:
#          ff        ee        tt        uu
# 0  0.619562  0.348882  0.824261  0.974331
# 1  0.335243  0.064855  0.540112  0.027981
# 2  0.213909  0.927155  0.484550  0.629162
# 3  0.651557  0.133179  0.598534  0.453358

# %%
# Initialize DataFrame with custom data
data = {'ID': [1, 2, 3], 'Names': ['Kate', 'John', 'Max'], 'Age': [50, 25, 41], 'Values': [3, 4, 8]}
df = pd.DataFrame(data=data, columns = ['ID', 'Names', 'Age', 'Values', 'Country'])

# Set one of the columns as index
df2 = df.set_index('ID')
 # Remove index name
df2.index.name = None

# Re-setting index
df3 = df2.copy()
df3.reset_index(inplace = True, drop = True) # drop = True; denies addition of old index to columns

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Values</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>4</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Values</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>John</td>
#       <td>25</td>
#       <td>4</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Max</td>
#       <td>41</td>
#       <td>8</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Values</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>John</td>
#       <td>25</td>
#       <td>4</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Max</td>
#       <td>41</td>
#       <td>8</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Modifying DataFrame

# %% [markdown]
# ### Renaming columns

# %%
data = {'ID': [1, 2, 3],'Names': ['Kate', 'John', 'Max'],'Age': [50, 25, 41], 'Values': [3, 4, 8]}
df = pd.DataFrame(data=data)
df2 = df.copy()
df.rename(columns = {"Names": "Name", "Age": "Alter"}, inplace = True)
display_side_by_side(df2,df)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Alter</th>
#       <th>ID</th>
#       <th>Name</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Sort data frame by colum values

# %%
data = {'ID': [1, 2, 3],'Names': ['Kate', 'John', 'Max'],'Age': [50, 25, 25], 'Values': [3, 4, 8]}
df = pd.DataFrame(data=data)

df2 = df.sort_values(['Age','Names'], ascending  = [True, False]).copy()

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>25</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Sort data frame by colums, custom order

# %%
data = {'ID': [1, 2, 3],'Names': ['Kate', 'John', 'Max'],'Age': [50, 25, 41], 'Values': [3, 4, 8]}
df = pd.DataFrame(data=data)
df2 = df.copy()
df2.index = pd.Categorical(df2.index, [2,0,1])
df2 = df2.sort_index(axis = 0)
display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Change DataFrame column order

# %%
data = {'ID': [1, 2,], 'Names': ['John', 'Max'], 'Vals1': [50, 41], 'Vals2': [4.0, 8.0], 'Vals3': ['4.4', '3.1']}
df = pd.DataFrame(data = data)
df2 = df.iloc[:, ::-1].copy()
df3 = df[['Vals2', 'Names', 'Vals3', 'Vals1']].copy()
display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#       <th>Vals3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>John</td>
#       <td>50</td>
#       <td>4.0</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>3.1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Vals3</th>
#       <th>Vals2</th>
#       <th>Vals1</th>
#       <th>Names</th>
#       <th>ID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.4</td>
#       <td>4.0</td>
#       <td>50</td>
#       <td>John</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.1</td>
#       <td>8.0</td>
#       <td>41</td>
#       <td>Max</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Vals2</th>
#       <th>Names</th>
#       <th>Vals3</th>
#       <th>Vals1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.0</td>
#       <td>John</td>
#       <td>4.4</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.0</td>
#       <td>Max</td>
#       <td>3.1</td>
#       <td>41</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Changing data types

# %%
data = {'ID': [1, 2, 3],'Names': ['Kate', 'John', 'Max']
        ,'Vals1': [50, 25, 41], 'Vals2': [3.0, 4.0, 8.0], 'Vals3': ['3.0', '4.4', '3.1']}
df = pd.DataFrame(data=data)
df2 = df.copy()

# Here we convert to numpy data types instead of native python types (float/int)
# Numpy data types are of fixed size but are more efficient
df2['Vals1'] = df2['Vals1'].astype('float64')
df2['Vals2'] = df2['Vals2'].astype('int64')
df2['Vals3'] = df2['Vals3'].astype('float64') # string to float, see also pd.to_numeric

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#       <th>Vals3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>4.0</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>3.1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#       <th>Vals3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50.0</td>
#       <td>3</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25.0</td>
#       <td>4</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41.0</td>
#       <td>8</td>
#       <td>3.1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Add row to DataFrame

# %%
data = {'ID': [1, 2,], 'Names': ['John', 'Max'],'Vals1': [50, 41], 'Vals2': [4.0, 8.0], 'Vals3': ['4.4', '3.1']}
df = pd.DataFrame(data = data)

df2 = pd.DataFrame({'ID': [4], 'Names': ['Janet'], 'Vals1': [50], 'Vals2': [12.0], 'Vals3': ['2.9']})
df3 = df.append(df2, ignore_index = True)

display_side_by_side(df,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#       <th>Vals3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>John</td>
#       <td>50</td>
#       <td>4.0</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>3.1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#       <th>Vals3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>John</td>
#       <td>50</td>
#       <td>4.0</td>
#       <td>4.4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>3.1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>Janet</td>
#       <td>50</td>
#       <td>12.0</td>
#       <td>2.9</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Add column to DataFrame

# %%
df = pd.DataFrame(data = {'ID': [1, 2, 3], 'Names': ['John', 'Max', 'Jane'],'Vals1': [50, 41, 32]})
df2 = pd.DataFrame(data = {'Vals2': [0.8, 0.6, 0.4]})
df3 = pd.concat([df, df2], axis = 1)
display_side_by_side(df, df2, df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>John</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Max</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Jane</td>
#       <td>32</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Vals2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>John</td>
#       <td>50</td>
#       <td>0.8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>0.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Jane</td>
#       <td>32</td>
#       <td>0.4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Dropping from DataFrame

# %%
data = {'ID': [1, 2, 3, 4, 5, 6]
        ,'Names': ['Kate', 'John', 'Max', 'Mary', 'Pete', 'Miriam']
        ,'Age': [50, 25, 41, 99, 54, 23]
        ,'Values': [3, 4, 8, 4, 3, 4]
        ,'col': [None]}
df_orig = pd.DataFrame(data=data, index = ['a','b','c','d', 'e', 'f'])
df = df_orig.copy()

# Drop columns by column label
df.drop(['Age', 'Names'], axis = 1, inplace = True)

# Drop column by fancy indexing
df.drop(df.columns[0], axis = 1, inplace = True)

# Drop column by ugin del; is directly inplace!
del df['col']

# Drop rows by index label
df.drop(['b'], axis = 0 , inplace = True)

# Drop rows by index number
df.drop(df.index[[0]], axis = 0, inplace = True)

# Drop rows where value in column does not fulfill condition
df = df[df['Values'] <= 5]

# Drop first n = 1 rows
df.drop(df.head(1).index,inplace=True)

# Drop last n = 1 rows
df.drop(df.tail(1).index,inplace=True) # drop last n rows

display_side_by_side(df_orig,df)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#       <th>col</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>99</td>
#       <td>4</td>
#       <td>Mary</td>
#       <td>4</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>e</th>
#       <td>54</td>
#       <td>5</td>
#       <td>Pete</td>
#       <td>3</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>f</th>
#       <td>23</td>
#       <td>6</td>
#       <td>Miriam</td>
#       <td>4</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>e</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Drop columns except those we want to keep
data = {'ID': [1, 2, 3, 4], 'Names': ['Kate', 'John', 'Max', 'Mary'], 'Age': [50, 25, 41,99], 'Values': [3, 4, 8,4], 'col': [None]}
df = pd.DataFrame(data = data, index = ['a','b','c','d'])
columns_to_keep = ['Names', 'Values']
df2 = df[columns_to_keep].copy()
display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#       <th>col</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>99</td>
#       <td>4</td>
#       <td>Mary</td>
#       <td>4</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>Mary</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Altering DataFrame values

# %%
df = pd.DataFrame(np.arange(12).reshape(6,2), columns = ['ff', 'er'])
df2 = df.copy()

# Apply change to whole column
df2['ff'] *= 0.8

# Conditionally modify certain cells
df2.loc[df2['er'] < 7,'er'] -= 2

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>er</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>er</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.8</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.4</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>8.0</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Concatenate two columns into one

# %%
data = {'ID': [1, 2, 3],'Names': ['Kate', 'John', 'Max'], 'Occupation': ['CEO', 'Doctor', 'Driver']
        ,'Vals1': [50, 25, 41], 'Vals2': [3.0, 4.0, 8.0]}
df = pd.DataFrame(data=data)
df2 = df.copy()

df2['two_string_cols'] = df2['Names'] + '_' + df2['Occupation']
df2['str_and_numeric'] = df2['Names'] + '_' + df2['Vals2'].map(str)
df2['format_numerics'] = df2['Names'] + '_' + df2['Vals2'].map("{:.0f}".format)

display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Occupation</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>CEO</td>
#       <td>50</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>Doctor</td>
#       <td>25</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>Driver</td>
#       <td>41</td>
#       <td>8.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Occupation</th>
#       <th>Vals1</th>
#       <th>Vals2</th>
#       <th>two_string_cols</th>
#       <th>str_and_numeric</th>
#       <th>format_numerics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>CEO</td>
#       <td>50</td>
#       <td>3.0</td>
#       <td>Kate_CEO</td>
#       <td>Kate_3.0</td>
#       <td>Kate_3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>Doctor</td>
#       <td>25</td>
#       <td>4.0</td>
#       <td>John_Doctor</td>
#       <td>John_4.0</td>
#       <td>John_4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>Driver</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>Max_Driver</td>
#       <td>Max_8.0</td>
#       <td>Max_8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Calculating new column conditionally

# %%
data = {'ID': [1, 2, 3],'Names': ['Kate', 'John', 'Max'],'val1': [50, 25, 41], 'val2': [3.0, 0, 8.0]}
df = pd.DataFrame(data=data)
df2 = df.copy()
df3 = df.copy()

df2['val1/val2']  = df2['val1']/df2['val2']
df3['val1/val2']  = np.where(df2['val2'] != 0, df2['val1']/df2['val2'], np.nan)
df2['val1']/df2['val2']

display_side_by_side(df, df2, df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>val1</th>
#       <th>val2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>val1</th>
#       <th>val2</th>
#       <th>val1/val2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3.0</td>
#       <td>16.666667</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>0.0</td>
#       <td>inf</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>5.125000</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>val1</th>
#       <th>val2</th>
#       <th>val1/val2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3.0</td>
#       <td>16.666667</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>0.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8.0</td>
#       <td>5.125000</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Slicing data frame

# %% [markdown]
# ### Basic sclicing

# %%
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])

# Selecting columns
# Using single square brackets selects a Series from DataFrame. 
# Using multiple square brackets selects a slice of data frame (possibly with muliple columns) 
df['ff'] # returns Series
df[['ff']] # returns DataFrame with one column
df[['ff', 'ee']] # returns DataFrame with two columns
df.loc[:,['ee', 'tt']]
df.iloc[:,0] # by position in frame
df.iloc[:,0:3] # first 3 columns

# Selecting rows
df.loc['first'] # by index
df.loc[~df.index.isin(['first'])] # rows except index 'first'
df.loc[['first', 'fourth']] # by index multiple rows
df[0:3]
df.iloc[0:2] # by position in frame

# Using data[2] or data['label'] indexes the series itself, skipping the iloc/loc
# attributes. This is syntatic sugar, but it is safer to use iloc/loc attributes
# explicitly in order avoid confusion querying between index label and index position.

display_side_by_side(df, df.loc[:,['ee','tt']], df.iloc[0:2], df.loc[~df.index.isin(['first'])], df.iloc[:,0:3]
)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.546635</td>
#       <td>0.327983</td>
#       <td>0.414851</td>
#       <td>0.409180</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.673270</td>
#       <td>0.316543</td>
#       <td>0.359522</td>
#       <td>0.427785</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.299157</td>
#       <td>0.036700</td>
#       <td>0.931771</td>
#       <td>0.234175</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.235387</td>
#       <td>0.170907</td>
#       <td>0.303086</td>
#       <td>0.538033</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ee</th>
#       <th>tt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.327983</td>
#       <td>0.414851</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.316543</td>
#       <td>0.359522</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.036700</td>
#       <td>0.931771</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.170907</td>
#       <td>0.303086</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.546635</td>
#       <td>0.327983</td>
#       <td>0.414851</td>
#       <td>0.409180</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.673270</td>
#       <td>0.316543</td>
#       <td>0.359522</td>
#       <td>0.427785</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>second</th>
#       <td>0.673270</td>
#       <td>0.316543</td>
#       <td>0.359522</td>
#       <td>0.427785</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.299157</td>
#       <td>0.036700</td>
#       <td>0.931771</td>
#       <td>0.234175</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.235387</td>
#       <td>0.170907</td>
#       <td>0.303086</td>
#       <td>0.538033</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.546635</td>
#       <td>0.327983</td>
#       <td>0.414851</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.673270</td>
#       <td>0.316543</td>
#       <td>0.359522</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.299157</td>
#       <td>0.036700</td>
#       <td>0.931771</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.235387</td>
#       <td>0.170907</td>
#       <td>0.303086</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Conditional slicing/indexing (boolean masking)

# %%
data = {'ID': [1, 2, 3, 4], 'Names': ['Kate', 'John', 'Max', 'Mary'], 'Age': [50, 25, 41,99], 'Values': [3, 4, 8,4]}
df = pd.DataFrame(data=data, index = ['a','b','c','d'])

# Get row slice fulfilling a condition along one column, return only
# certain columns
df2 = pd.DataFrame(df.loc[df['Values'] < 5,  ['Names', 'Values']].copy())

# Same as above but multiple conditions, return all columns tha match
df3 = df.loc[(df['Values'] < 5 ) & (df['Names'] == 'John'), ].copy()

# Conditional indexing by preserving original dimensions
df4 = df.where(df['Values'] < 5).copy()

display_side_by_side(df,df2,df3,df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>99</td>
#       <td>4</td>
#       <td>Mary</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>Mary</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>b</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>50.0</td>
#       <td>1.0</td>
#       <td>Kate</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>25.0</td>
#       <td>2.0</td>
#       <td>John</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>99.0</td>
#       <td>4.0</td>
#       <td>Mary</td>
#       <td>4.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Slicing based on partial string match in column

# %%
data = {'ID': [1, 2, 3, 4], 'Names': ['Kare', 'John', 'Max', 'Mary'], 'Age': [50, 25, 41,99], 'Values': [3, 4, 8,4]}
df = pd.DataFrame(data=data, index = ['a','b','c','d'])
df2 = df.copy()

df2 = df2[df2['Names'].str.contains("ar")]

display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kare</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>99</td>
#       <td>4</td>
#       <td>Mary</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kare</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>99</td>
#       <td>4</td>
#       <td>Mary</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Iterating over DataFrame

# %%
data = {'Names': ['Kate', 'John', 'Max'], 'Age': [50, 25, 41], 'Weight': [62, 76, 98]}
df = pd.DataFrame(data = data)

# "Right" way with df.iterrows 
for index, row in df.iterrows():
    print(index, row['Age'])

print('-'*30)    

# "Normal" integer looping over rows
for counter in range(0,len(df)):
    print(df.iloc[counter,0])
# Out:
# 0 50
# 1 25
# 2 41
# ------------------------------
# 50
# 25
# 41

# %%
# Set values during row iteration
data = {'Names': ['Kate', 'John', 'Max'], 'Age': [50, 25, 41], 'Weight': [62, 76, 98]}
df = pd.DataFrame(data = data)
df2 = df.copy()

for index, row in df2.iterrows():
    if row['Names'] == 'John':
        df2.set_value(index, 'Weight', 100)
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Names</th>
#       <th>Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>Kate</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>John</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>Max</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Names</th>
#       <th>Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>Kate</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>John</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>Max</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## About chain indexing

# %%
# A rule of thub is that any time you see back-to-back square brackets,
# ][, you're asking for trouble. Replace that with a .loc[] or .iloc[]
# and you'll be set. Let's see an example

df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])
display(df)
print(df['ee']['second']) # bad practice
print(df.loc['second', 'ee']) # good practice
# Out:
#               ff        ee        tt       uuu
# first   0.040172  0.918014  0.284994  0.247170
# second  0.790604  0.712705  0.744147  0.604816
# third   0.234373  0.951541  0.070026  0.682034
# fourth  0.964662  0.735669  0.969218  0.734263
# 0.71270500583
# 0.71270500583

# %%
# Another example
df = pd.DataFrame()
df['x'] = np.arange(10,14)
df['value'] = np.arange(200,204)
display(df)

print(df[ df['x']== 10 ]['value']) # bad practice
print('-'*30)
print(df.loc[df['x'] == 10, 'value']) # good practice

# The bad practice option would't even work in the case
# we want to assign a new value for the returned obseravtions

#df[ df['x']== 10 ]['value'] = 1000 # this throws error!
print('-'*30)
df.loc[df['x'] == 10, 'value'] = 1000
display(df)
# Out:
#     x  value
# 0  10    200
# 1  11    201
# 2  12    202
# 3  13    203
# 0    200
# Name: value, dtype: int32
# ------------------------------
# 0    200
# Name: value, dtype: int32
# ------------------------------
#     x  value
# 0  10   1000
# 1  11    201
# 2  12    202
# 3  13    203

# %% [markdown]
# ## Method chaining

# %%
# 'Pandorable' way is to chain methods operating on DataFrame:
data = {'Names': ['Kate', 'John', 'Max'],'Age': [50, 25, 41], 'Weight': [62, 76, 98]}
df = pd.DataFrame(data=data)

df2 = df.copy()
# Not-so-good practice: two lines of code
df2 = df2.drop(df2[df2['Age'] == 25].index)
df2.rename(columns={'Weight': 'Weight (kg)'}, inplace = True)

df3 = df.copy()
# Better practice - on line of code
df3 = df3.drop(df3[df3['Age'] == 25].index).rename(columns = {'Weight': 'Weight (kg)'}).copy()

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Names</th>
#       <th>Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>Kate</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>John</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>Max</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Names</th>
#       <th>Weight (kg)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>Kate</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>Max</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Names</th>
#       <th>Weight (kg)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>Kate</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>Max</td>
#       <td>98</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Data types and scales
#
# This section is till incomplete!

# %% [markdown]
# In general, there are 4 types of data scales
# <ol>
#   <li>Ratio scale, e.g. height</li>
#   <li>Inteval scale, e.g. temperature</li>
#   <li>Ordinal scale, e.g. grading scale</li>
#   <li>Nominal scale, e.g. school names</li>
# </ol>

# %%
# Specify a column in DataFrame to be gatecorigal, sort by categorical order
df = pd.DataFrame(['E','M','L','M','I','A','B','B','M'], columns = ['Grades'])

# Categories need to be passed in ascending order!
df['Grades'] = df['Grades'].astype('category', categories = ['I','A','B','C','M','E','L'], ordered = True)
df2 = df.sort_values(['Grades'], ascending  = False).copy()
df3 = df[df['Grades'] >= 'M'].copy()

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Grades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>E</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>L</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>I</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>A</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>M</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Grades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>L</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>E</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>A</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>I</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Grades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>E</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>L</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>M</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# # Hierarchical indexing (MultiIndex)

# %% [markdown]
# ## Initialize DataFrame with hierarchical indexing

# %%
df = pd.DataFrame(data = np.arange(12).reshape((4,3))
                  ,index = [['a','a','b','b',], [1,2] * 2]
                  ,columns = [['col1','col1','col2'], ['ff','gg','ff']])
display_side_by_side(df)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">col1</th>
#       <th>col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>ff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Modifying MultiIndex DataFrame

# %% [markdown]
# ### Add second index to existing DataFrame

# %%
df = pd.DataFrame(data = np.arange(12).reshape((4,3)), columns = ['col1','col1','col2'])
df2 = df.copy()
df2.set_index([df2.index, 'col2'], inplace = True)
df2.index.names = ['Index1', 'Index2']
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>col1</th>
#       <th>col1</th>
#     </tr>
#     <tr>
#       <th>Index1</th>
#       <th>Index2</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>2</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>5</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <th>8</th>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <th>11</th>
#       <td>9</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Add new column to existing MultiIndex DataFrame

# %%
df = pd.DataFrame(data = np.arange(16).reshape((4,4))
                  ,index = [['a','a','b','b',], [1,2] * 2]
                  ,columns = [['col1','col1','col2','col2'], ['ff','gg','ff','gg']])

# Add new column to MultiIndex frame
df2 = df.copy()
df2['col2', 'dd'] = [0, 1, 2, 4]
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">col1</th>
#       <th colspan="2" halign="left">col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>ff</th>
#       <th>gg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">col1</th>
#       <th colspan="3" halign="left">col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>dd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Get different MultiIndex levels

# %%
df = pd.DataFrame(data = np.arange(12).reshape((4,3))
                  ,index = [['a','a','b','b',], [1,2] * 2]
                  ,columns = [['col1','col1','col2'], ['ff','gg','ff']])

print(df.columns.get_level_values(0))
print(df.columns.get_level_values(1))
print(df.index.get_level_values(0))
print(df.index.get_level_values(1))
# Out:
# Index(['col1', 'col1', 'col2'], dtype='object')
# Index(['ff', 'gg', 'ff'], dtype='object')
# Index(['a', 'a', 'b', 'b'], dtype='object')
# Int64Index([1, 2, 1, 2], dtype='int64')

# %% [markdown]
# ## Quering MultiIndex DataFrames

# %%
df = pd.DataFrame(data = np.arange(16).reshape((4,4))
                  ,index = [['a','a','b','b',], [1,2] * 2]
                  ,columns = [['col1','col1','col2','col2'], ['ff','gg','ff','gg']])

# Get observations from certain column level
df2 = df.iloc[:, df.columns.get_level_values(1) == 'gg'].copy()
df2b = df.iloc[:, df.columns.get_level_values(1).isin(['gg','ee'])].copy()

# Get observations from certain index level
df3 = df.iloc[df.index.get_level_values(1) == 2,:].copy()

# Get observations from certain column levels (multi-condition)
df4 = df.iloc[:, (df.columns.get_level_values(0) == 'col1') & (df.columns.get_level_values(1) == 'gg')].copy()

display_side_by_side(df,df2,df2b,df3,df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">col1</th>
#       <th colspan="2" halign="left">col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>ff</th>
#       <th>gg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>gg</th>
#       <th>gg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>gg</th>
#       <th>gg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">col1</th>
#       <th colspan="2" halign="left">col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>ff</th>
#       <th>gg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <th>2</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <th>2</th>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>col1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>gg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# # Data wrangling tricks

# %% [markdown]
# ## Mappings for column values

# %% [markdown]
# ### One-to-one mappings

# %% [markdown]
# #### Map from dict

# %%
data = {'ID': [1, 2, 3,4],'Names': ['Kate', 'John', 'Max','Kate'],'Age': [50, 25, 41,89], 'Values': [3, 4, 8, 12]}
df = pd.DataFrame(data = data)
df2 = df.copy()

# Mapping from user defined dict
age_mapping = {25:0, 41:1, 50:2, 89:3}
df2['AgeOrder'] = df2['Age'].map(age_mapping)
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>89</td>
#       <td>4</td>
#       <td>Kate</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#       <th>AgeOrder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>89</td>
#       <td>4</td>
#       <td>Kate</td>
#       <td>12</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# #### Assign unique identifier to column values

# %%
data = {'ID': [1, 2, 3,4], 'Names': ['Kate', 'John', 'Max','Kate'], 'Age': [50, 25, 41,89], 'Values': [3, 4, 8, 12]}
df = pd.DataFrame(data = data)
df2 = df.copy()

# Assign unique identifier to values in column (Names -> NameID)
d = {key: value for (key, value) in zip(df['Names'].unique(),range(len(df['Names'].unique())))}
df2['NameID'] = df2['Names'].map(d)
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>89</td>
#       <td>4</td>
#       <td>Kate</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#       <th>NameID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>89</td>
#       <td>4</td>
#       <td>Kate</td>
#       <td>12</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# #### Map column string values to lowercase

# %%
data = {'ID': [1, 2, 3,4], 'Names': ['Kate', 'JoHn', 'MA4','KATE'], 'Values': [3, 4, 8, 12]}
df = pd.DataFrame(data = data)
df2 = df.copy()
df2['Names'] = df2['Names'].map(lambda x: x if type(x)!=str else x.lower())

display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>JoHn</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>MA4</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>KATE</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>john</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>ma4</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>kate</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# #### Using regex with map

# %%
import re
data = {'ID': [1, 2, 3,4], 'Names': ['Kate', 'John', 'Max','Kate'], 'Values': ['foff', 'ss-d', '8', '-rrgr']}
df = pd.DataFrame(data = data)
df2 = df.copy()

# also includes the delimiter!
regex2 = re.compile("(?:-).*")
df2['Values'] = df2['Values'].replace(to_replace = regex2, value = 'REPLACED')

display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>foff</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>ss-d</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Kate</td>
#       <td>-rrgr</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>foff</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>ssREPLACED</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Kate</td>
#       <td>REPLACED</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Map values to ranges/groups

# %%
data = {'ID': [1, 2, 3,4], 'Names': ['Kate', 'John', 'Max','Kate'], 'Age': [39, 18, 25,75], 'Values': [3, 4, 8, 12]}
df = pd.DataFrame(data = data)
df2 = df.copy()

# Even-sized bins 
df2['ValGroup1'] = pd.cut(df2['Values'] , 4, right = True) # 4 bins, includes rightmost edge
                    
# Relative-sized bins 
df2['ValGroup2'] = pd.qcut(df2['Values'], 4)

# Custom bin sizes and labels
df2['AgeGroup'] = pd.cut(df2['Age'], [0, 20, 40, 60, 80, np.inf], labels = [1,2,3,4,5], right = True)

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>39</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>75</td>
#       <td>4</td>
#       <td>Kate</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#       <th>ValGroup1</th>
#       <th>ValGroup2</th>
#       <th>AgeGroup</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>39</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#       <td>(2.991, 5.25]</td>
#       <td>[3, 3.75]</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>2</td>
#       <td>John</td>
#       <td>4</td>
#       <td>(2.991, 5.25]</td>
#       <td>(3.75, 6]</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25</td>
#       <td>3</td>
#       <td>Max</td>
#       <td>8</td>
#       <td>(7.5, 9.75]</td>
#       <td>(6, 9]</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>75</td>
#       <td>4</td>
#       <td>Kate</td>
#       <td>12</td>
#       <td>(9.75, 12]</td>
#       <td>(9, 12]</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Categorical variable to dummy columns

# %%
df = pd.DataFrame({'Category': ['Type1','Type2','Type1','Type3'], 'Value': np.random.rand(4)})

df2 = df.copy()
df2['Category'] = df2['Category'].astype('category', categories = ['Type1','Type2','Type3'], ordered = True)
df2 = pd.get_dummies(df2, prefix = ['Category'])

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Type1</td>
#       <td>0.673582</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Type2</td>
#       <td>0.488924</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Type1</td>
#       <td>0.154963</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Type3</td>
#       <td>0.625021</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Value</th>
#       <th>Category_Type1</th>
#       <th>Category_Type2</th>
#       <th>Category_Type3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.673582</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.488924</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.154963</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.625021</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Change between long/wide format

# %% [markdown]
# ### Wide to long

# %%
# Create data
df = pd.DataFrame(data = np.arange(9).reshape((3,3)), columns = [['col1','col2','col3']])

df2 = pd.DataFrame(data = np.arange(12).reshape((4,3))
                  ,index = [['a','a','b','b',], [1,2] * 2]
                  ,columns = [['col1','col1','col2'], ['ff','gg','ff']])

# Simple melt
df3 = pd.melt(df).copy()
df4 = pd.melt(df2).copy()

display_side_by_side(df,df3,df2,df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>col1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>col1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>col1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>col2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>col2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>col2</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>col3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>col3</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>col3</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">col1</th>
#       <th>col2</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ff</th>
#       <th>gg</th>
#       <th>ff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
#       <th>1</th>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable_0</th>
#       <th>variable_1</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>col1</td>
#       <td>ff</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>col1</td>
#       <td>ff</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>col1</td>
#       <td>ff</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>col1</td>
#       <td>ff</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>col1</td>
#       <td>gg</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>col1</td>
#       <td>gg</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>col1</td>
#       <td>gg</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>col1</td>
#       <td>gg</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>col2</td>
#       <td>ff</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>col2</td>
#       <td>ff</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>col2</td>
#       <td>ff</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>col2</td>
#       <td>ff</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Long to wide

# %%
# Create data
df = pd.DataFrame({
         'name1': ['A','A','B','B']
        ,'name2': ['A','B','A','B']
        ,'val': [5,9,7,3]})

df2 = df.pivot(index = 'name1', columns = 'name2', values = 'val').copy()

# If the above does not work, try pivot_table which is a generalization of
# pivot for duplicate entries.
df3 = df.pivot_table(values = 'val', index = 'name1', columns = 'name2').copy()

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name1</th>
#       <th>name2</th>
#       <th>val</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>A</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>B</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>A</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>B</td>
#       <td>B</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name2</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#     <tr>
#       <th>name1</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>5</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name2</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#     <tr>
#       <th>name1</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>5</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Pivot_table might not work with non-numeric columns
# In this case try the following (does however not work
# with duplicate indices

df = pd.DataFrame({'index' : range(8)
                  ,'variable1' : ["A","A","B","B","A","B","B","A"]
                  ,'variable2' : ["a","b","a","b","a","b","a","b"]
                  ,'result': ["on","off","off","on","on","off","off","on"]})

df1 = df.copy()
unstack_cols = ['variable1', 'variable2']
df1 = df.set_index(['index'] + unstack_cols).unstack(level = unstack_cols)

display_side_by_side(df,df1)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>result</th>
#       <th>variable1</th>
#       <th>variable2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>on</td>
#       <td>A</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>off</td>
#       <td>A</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>off</td>
#       <td>B</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>on</td>
#       <td>B</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>on</td>
#       <td>A</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>off</td>
#       <td>B</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>off</td>
#       <td>B</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>on</td>
#       <td>A</td>
#       <td>b</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">result</th>
#     </tr>
#     <tr>
#       <th>variable1</th>
#       <th colspan="2" halign="left">A</th>
#       <th colspan="2" halign="left">B</th>
#     </tr>
#     <tr>
#       <th>variable2</th>
#       <th>a</th>
#       <th>b</th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#     <tr>
#       <th>index</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>on</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>None</td>
#       <td>off</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>None</td>
#       <td>None</td>
#       <td>off</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>on</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>on</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>off</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>None</td>
#       <td>None</td>
#       <td>off</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>None</td>
#       <td>on</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Long to wide with time series type of data
data = { 'ID': [1, 1, 2, 2, 1, 1, 2, 2]
        ,'Date': ['2007-01-01','2007-01-01', '2007-01-01','2007-01-01', '2007-01-02','2007-01-02', '2007-01-02','2007-01-02']
        ,'Type': ['type1','type2','type1','type2','type1','type2','type1','type2']
        ,'Values': np.arange(8)}
df = pd.DataFrame(data = data)

df2 = df.groupby(['Date','ID','Type']).sum().unstack('ID').copy()
new_col_names = ['_'.join((str(b),a)) for a,b in df2.columns.get_values()] # flatten columns
df2.columns = new_col_names

df3 = df.groupby(['Date','ID','Type']).sum().unstack(['ID','Type']).copy()
new_col_names = ['_'.join((a,str(b),c)) for a,b,c in df3.columns.get_values()]
df3.columns = new_col_names

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>ID</th>
#       <th>Type</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2007-01-01</td>
#       <td>1</td>
#       <td>type1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2007-01-01</td>
#       <td>1</td>
#       <td>type2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2007-01-01</td>
#       <td>2</td>
#       <td>type1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2007-01-01</td>
#       <td>2</td>
#       <td>type2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2007-01-02</td>
#       <td>1</td>
#       <td>type1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2007-01-02</td>
#       <td>1</td>
#       <td>type2</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2007-01-02</td>
#       <td>2</td>
#       <td>type1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2007-01-02</td>
#       <td>2</td>
#       <td>type2</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>1_Values</th>
#       <th>2_Values</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">2007-01-01</th>
#       <th>type1</th>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>type2</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">2007-01-02</th>
#       <th>type1</th>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>type2</th>
#       <td>5</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values_1_type1</th>
#       <th>Values_1_type2</th>
#       <th>Values_2_type1</th>
#       <th>Values_2_type2</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2007-01-01</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2007-01-02</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Database-like joins

# %%
# Create data
df = pd.DataFrame(data = np.arange(12).reshape((3,4)), columns = [['col1','col2','col3','col4']])
df2 = pd.DataFrame({'key': [0,1,2], 'vals': [4,6,8]})
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>vals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Different merges
df3 = pd.merge(df, df2,left_index = True, right_on = 'key',how = 'left')
df4 = pd.merge(df, df2,left_on = 'col2', right_on = 'key',how = 'left')
df5 = pd.merge(df, df2,left_on = 'col2', right_on = 'key',how = 'right')
df6 = pd.merge(df, df2,left_on = 'col2', right_on = 'key',how = 'inner')
df7 = pd.merge(df, df2,left_on = 'col2', right_on = 'key',how = 'outer')

# Right and left joins are basically the same, just different way around
# Compare df8 to df5
df8 = pd.merge(df2, df, left_on = 'key', right_on = 'col2', how = 'left')

display_side_by_side(df3,df4,df5,df6,df7,df8)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#       <th>key</th>
#       <th>vals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>0</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>2</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#       <th>key</th>
#       <th>vals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#       <th>key</th>
#       <th>vals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#       <th>key</th>
#       <th>vals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#       <th>key</th>
#       <th>vals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>11.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2.0</td>
#       <td>8.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>vals</th>
#       <th>col1</th>
#       <th>col2</th>
#       <th>col3</th>
#       <th>col4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>4</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>8</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Get rows which are bot in another DataFrame
df1 = pd.DataFrame(data = {'col1' : [1, 2, 3, 4, 5], 'col2' : [10, 11, 12, 13, 14]}) 
df2 = pd.DataFrame(data = {'col1' : [1, 2, 3], 'col2' : [10, 11, 12]})
df = df1[~df1.isin(df2)].dropna()
display_side_by_side(df1,df2,df)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>4.0</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.0</td>
#       <td>14.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Aggregating infromation in DataFrame

# %% [markdown]
# ### Simple means, medians etc.

# %%
# Simple example
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])
df.iloc[:2,1] = np.nan
display(df)

# Mean by column, change axis=0 to get rows
display(df.mean(axis = 1, skipna = False))
display(df.mean(axis = 1, skipna = True))
# Out:
#               ff        ee        tt       uuu
# first   0.913663       NaN  0.138403  0.741817
# second  0.591420       NaN  0.083292  0.429265
# third   0.323967  0.049306  0.258327  0.280430
# fourth  0.118102  0.686354  0.122944  0.620003
# first          NaN
# second         NaN
# third     0.228007
# fourth    0.386851
# dtype: float64
# first     0.597961
# second    0.367992
# third     0.228007
# fourth    0.386851
# dtype: float64

# %% [markdown]
# ### Apply means, medians etc. to subportion of data frame

# %%
# Easy way to calculate aggregations using lambdas and apply
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])
cols_to_apply = ['ff', 'tt', 'uuu']
df2 = pd.DataFrame(df.apply(lambda x: np.max(x[cols_to_apply]), axis = 1), columns = ['Max of column subset'])
df3 = pd.DataFrame(df.apply(lambda x: np.mean(x[cols_to_apply]), axis = 1), columns = ['Mean of column subset'])

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.948801</td>
#       <td>0.434103</td>
#       <td>0.412044</td>
#       <td>0.262166</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.250648</td>
#       <td>0.701868</td>
#       <td>0.518671</td>
#       <td>0.820843</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.518496</td>
#       <td>0.464663</td>
#       <td>0.958961</td>
#       <td>0.657876</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.325886</td>
#       <td>0.307103</td>
#       <td>0.093499</td>
#       <td>0.053628</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Max of column subset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.948801</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.820843</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.958961</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.325886</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mean of column subset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.541003</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.530054</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.711777</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.157671</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
df = pd.DataFrame({'name1':['A','A','B','B'],'val1':[3.1,8,1.2,4.5],'val2':[5,9,7,3]})

rows_to_apply = df[df['val2'] < 6].index
cols_to_apply = ['val1']

display_side_by_side(df)
display(rows_to_apply)

#df2 = df.loc[rows_to_apply, cols_to_apply]

df2 = pd.DataFrame(df.apply(lambda x: np.mean(x.loc[rows_to_apply, cols_to_apply]), axis = 0))
df2
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name1</th>
#       <th>val1</th>
#       <th>val2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>3.1</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>8.0</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>1.2</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>B</td>
#       <td>4.5</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">
# Int64Index([0, 3], dtype='int64')
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-31-1a5ea5c5630b> in <module>()
#       9 #df2 = df.loc[rows_to_apply, cols_to_apply]
#      10
# ---> 11 df2 = pd.DataFrame(df.apply(lambda x: np.mean(x.loc[rows_to_apply, cols_to_apply]), axis = 0))
#      12 df2
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4059                     if reduce is None:
#    4060                         reduce = True
# -> 4061                     return self._apply_standard(f, axis, reduce=reduce)
#    4062             else:
#    4063                 return self._apply_broadcast(f, axis)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4155             try:
#    4156                 for i, v in enumerate(series_gen):
# -> 4157                     results[i] = func(v)
#    4158                     keys.append(v.name)
#    4159             except Exception as e:
#
# <ipython-input-31-1a5ea5c5630b> in <lambda>(x)
#       9 #df2 = df.loc[rows_to_apply, cols_to_apply]
#      10
# ---> 11 df2 = pd.DataFrame(df.apply(lambda x: np.mean(x.loc[rows_to_apply, cols_to_apply]), axis = 0))
#      12 df2
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     787
#     788         # no multi-index, so validate all of the indexers
# --> 789         self._has_valid_tuple(tup)
#     790
#     791         # ugly hack for GH #836
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     139         for i, k in enumerate(key):
#     140             if i >= self.obj.ndim:
# --> 141                 raise IndexingError('Too many indexers')
#     142             if not self._has_valid_type(k, i):
#     143                 raise ValueError("Location based indexing can only have [%s] "
#
# IndexingError: ('Too many indexers', 'occurred at index name1')

# %% [markdown]
# ### 'Group by' in various forms

# %%
data = {'ID': [1, 1, 2], 'Names': ['Kate', 'John', 'Max'], 'Age': [50, 25, 40], 'Values': [3, 4, 8]}
df = pd.DataFrame(data = data, index = ['first','second','first'])
df.index.name = 'Index'

result1 = df.groupby(['ID'])['Values'].sum()
result1 = pd.DataFrame(result1)

result2 = df.groupby([df.index])['Age'].mean()
result2 = pd.DataFrame(result2)

result3 = df.groupby([df.index])['Age'].count()
result3 = pd.DataFrame(result3)

display_side_by_side(df,result1,result2,result3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Values</th>
#     </tr>
#     <tr>
#       <th>Index</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>50</td>
#       <td>1</td>
#       <td>Kate</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>25</td>
#       <td>1</td>
#       <td>John</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>first</th>
#       <td>40</td>
#       <td>2</td>
#       <td>Max</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#     </tr>
#     <tr>
#       <th>Index</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>25</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#     </tr>
#     <tr>
#       <th>Index</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# #### Table of counts/means for categorical variable

# %%
data = {'ID': [1, 1, 1, 2, 2], 'Type': ['moo', 'boo', 'boo', np.nan, 'moo'], 'Values': [3, 4, 6, 7, 4]}
df = pd.DataFrame(data = data)

# They magic touch is reset_index: count calculation is done on this new column!
df2 = df[['ID', 'Type']].reset_index().groupby(['ID','Type'], as_index = False).count()
df2.columns = ['ID', 'Type', 'count']

# Carefull with missing values! This works with them and assign them as -1
df3 = df[['ID', 'Type']].fillna(-1).reset_index().groupby(['ID','Type'], as_index = False).count()
df3.columns = ['ID', 'Type', 'count']

df4 = df[['ID','Type','Values']].copy().groupby(['ID','Type'], as_index = False).mean()
df4.columns = ['ID', 'Type', 'mean']

display_side_by_side(df,df2,df3,df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Type</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>moo</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>boo</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>boo</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>NaN</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>moo</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Type</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>boo</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>moo</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>moo</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Type</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>boo</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>moo</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>-1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>moo</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Type</th>
#       <th>mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>boo</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>moo</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>moo</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# #### Table of counts for continuous variable

# %%
def continuous_binning(pdseries, bins):
    '''
    Bins continious variable. Treats also NaNs
    Returns data frame.
    '''    
    df_test = pd.DataFrame()
    df_test['bins'] = pd.cut(pdseries, bins, right = True)
    df_test = df_test[['bins']].reset_index().groupby(['bins'], as_index = False).count()
    df_test.columns = ['bins','count']
    df_nans = pd.DataFrame({'bins': ['NaN'], 'count': [len(pdseries[np.isnan(pdseries)])]})
    df_test = df_test.append(df_nans, ignore_index = True)
    return df_test


df = pd.DataFrame(data = {'ID': [1, 2, 3,4, 5], 'Values': [3.5, 4, 8.7, 12.6, 7]})
df2 = pd.DataFrame(data = {'ID': [1, 2, 3,4, 5], 'Values': [3.5, 4, 8.7, 12.6, np.nan]})
bins = [0, 3, 6, 9, 12, 15, np.inf]

y = df['Values']
df3 = continuous_binning(y, bins)

y = df2['Values']
df4 = continuous_binning(y, bins)

display_side_by_side(df,df3,df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>8.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>12.6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>7.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bins</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>(0, 3]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>(3, 6]</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>(6, 9]</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>(9, 12]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>(12, 15]</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>(15, inf]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bins</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>(0, 3]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>(3, 6]</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>(6, 9]</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>(9, 12]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>(12, 15]</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>(15, inf]</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Select sum of first greatest N values within group
data = {'ID': [1, 2, 1, 2, 1], 'Values': [3, 9, 8, 7, 3]}
df = pd.DataFrame(data = data)

df2 = df.copy()
df2.sort_values(['ID','Values'], ascending = [True, False], inplace = True)
df2 = df2.groupby('ID').head(2)
df2 = pd.DataFrame(df2.groupby(['ID'])['Values'].sum().sort_values(ascending = False))

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#     <tr>
#       <th>ID</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Combination of group by and apply: caluclation between grouped columns
# Example: Total price of each product bought

df = pd.DataFrame({'Product': [1, 2, 1, 2], 'Quantity': [1, 3, 2, 2], 'Price': [10, 20, 5, 2]})
df2 = pd.DataFrame(df.groupby(['Product']).apply(lambda df, a, b: sum(df[a] * df[b]), 'Quantity', 'Price'))
df2.columns = ['Total sell price']
display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Price</th>
#       <th>Product</th>
#       <th>Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total sell price</th>
#     </tr>
#     <tr>
#       <th>Product</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>64</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Agg method

# %%
# Agg is similar to apply, but agg gives the flexibility of
# applying multiple functions at once. Agg() is handy at handling
# DataFrameGroupBy objects compared to apply()

df = pd.DataFrame({"name":["Foo", "Baar", "Foo", "Baar"]
                   ,"score_1":[5,10,15,10]
                   ,"score_2" :[10,15,10,25]
                   ,"score_3" : [10,20,30,40]})

# Mean and sum of "score_2" grouped by "name" and "score_1" columns using apply
print(df.groupby(["name", "score_1"])["score_2"].apply(lambda x : x.mean()))
print(df.groupby(["name", "score_1"])["score_2"].apply(lambda x : x.sum()))

# Same with agg(), and even more aggregations applied to multiple columns, all at the same go!
df2 = df.groupby(["name", "score_1"]).agg({"score_2" :[np.mean, np.sum, np.max, np.min], "score_3": [np.mean]}).copy()

# You can also pass in a lambda function to agg
df3 = df.groupby(["name", "score_1"]).agg({ "score_3": lambda x: x.mean()}).copy()

display_side_by_side(df,df2,df3)
# Out:
# name  score_1
# Baar  10         20.0
# Foo   5          10.0
#       15         10.0
# Name: score_2, dtype: float64
# name  score_1
# Baar  10         40
# Foo   5          10
#       15         10
# Name: score_2, dtype: int64
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>score_1</th>
#       <th>score_2</th>
#       <th>score_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Foo</td>
#       <td>5</td>
#       <td>10</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Baar</td>
#       <td>10</td>
#       <td>15</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Foo</td>
#       <td>15</td>
#       <td>10</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Baar</td>
#       <td>10</td>
#       <td>25</td>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="4" halign="left">score_2</th>
#       <th>score_3</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>sum</th>
#       <th>amax</th>
#       <th>amin</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th>score_1</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baar</th>
#       <th>10</th>
#       <td>20</td>
#       <td>40</td>
#       <td>25</td>
#       <td>15</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Foo</th>
#       <th>5</th>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>score_3</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th>score_1</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baar</th>
#       <th>10</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Foo</th>
#       <th>5</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ### Pivot table

# %%
df = pd.DataFrame({"name":["Foo", "Baar", "Foo", "Baar"]
                   ,"name2":['mm','mm','mm','ee']
                   ,"score_1" :[10,15,10,25]
                   ,"score_2" : [10,20,30,40]})

# Basics
df2 = df.pivot_table(values='score_1', index='name', columns = 'name2', aggfunc = [np.mean,np.max]).copy()
df3 = df.pivot_table(values='score_1', index='name', columns = 'name2', aggfunc = [np.mean,np.min], margins = True).copy()

# Shares out of row sum
df4 = df.pivot_table(values = 'score_1', index = 'name', columns = 'name2', aggfunc = [np.sum], margins = True).copy()
df4.columns = df4.columns.get_level_values(1)
df4.drop(['All'], axis = 0 , inplace = True)
df4.fillna(0, inplace = True)
df5 = df4.copy()
for _, row in df5.iterrows():
    row[0:-1] = row[0:-1] / row[-1]

display_side_by_side(df,df2,df3)
display_side_by_side(df4, df5)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>name2</th>
#       <th>score_1</th>
#       <th>score_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Foo</td>
#       <td>mm</td>
#       <td>10</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Baar</td>
#       <td>mm</td>
#       <td>15</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Foo</td>
#       <td>mm</td>
#       <td>10</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Baar</td>
#       <td>ee</td>
#       <td>25</td>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">mean</th>
#       <th colspan="2" halign="left">amax</th>
#     </tr>
#     <tr>
#       <th>name2</th>
#       <th>ee</th>
#       <th>mm</th>
#       <th>ee</th>
#       <th>mm</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baar</th>
#       <td>25.0</td>
#       <td>15.0</td>
#       <td>25.0</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>Foo</th>
#       <td>NaN</td>
#       <td>10.0</td>
#       <td>NaN</td>
#       <td>10.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="3" halign="left">mean</th>
#       <th colspan="3" halign="left">amin</th>
#     </tr>
#     <tr>
#       <th>name2</th>
#       <th>ee</th>
#       <th>mm</th>
#       <th>All</th>
#       <th>ee</th>
#       <th>mm</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baar</th>
#       <td>25.0</td>
#       <td>15.000000</td>
#       <td>20.0</td>
#       <td>25.0</td>
#       <td>15.0</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>Foo</th>
#       <td>NaN</td>
#       <td>10.000000</td>
#       <td>10.0</td>
#       <td>NaN</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>All</th>
#       <td>25.0</td>
#       <td>11.666667</td>
#       <td>15.0</td>
#       <td>25.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name2</th>
#       <th>ee</th>
#       <th>mm</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baar</th>
#       <td>25.0</td>
#       <td>15.0</td>
#       <td>40.0</td>
#     </tr>
#     <tr>
#       <th>Foo</th>
#       <td>0.0</td>
#       <td>20.0</td>
#       <td>20.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name2</th>
#       <th>ee</th>
#       <th>mm</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Baar</th>
#       <td>0.625</td>
#       <td>0.375</td>
#       <td>40.0</td>
#     </tr>
#     <tr>
#       <th>Foo</th>
#       <td>0.000</td>
#       <td>1.000</td>
#       <td>20.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# <h1>Data cleaning</h1>

# %% [markdown]
# ## Find string from data frame column

# %%
data = {'ID': [1, 2, 3], 'Names': ['Kate', 'John', 'Max'], 'Age': [50, 25, 41], 'Values': [3, 4, 8]}
df = pd.DataFrame(data=data, columns = ['ID', 'Names', 'Age', 'Values', 'Country'])

df2 = df[df['Names'].str.contains("John")].copy()

display_side_by_side(df, df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Values</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Kate</td>
#       <td>50</td>
#       <td>3</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>4</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Max</td>
#       <td>41</td>
#       <td>8</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Names</th>
#       <th>Age</th>
#       <th>Values</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>John</td>
#       <td>25</td>
#       <td>4</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Replace all non-numerical values with NaN

# %%
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])
df.iloc[2,1] = 'dd'
df.iloc[1,2] = '-----'
df.iloc[2,2] = '#SomeErrorVal'
df2 = df.copy()

# Count amount of non-numeric in a column
print('Column ' + 'ee' + ' has {} non-numeric'.format(len(df.loc[pd.to_numeric(df['ee'], errors='coerce').isnull(), 'ee'])))

cols = ['ff', 'ee', 'tt', 'uuu']
for col in cols:
    df2[col][df2.apply(lambda x: np.isreal(x[col]) == True , axis = 1) == False] = np.nan

display_side_by_side(df,df2)
# Out:
# Column ee has 1 non-numeric
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.917584</td>
#       <td>0.0878392</td>
#       <td>0.0882069</td>
#       <td>0.727976</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.272932</td>
#       <td>0.500158</td>
#       <td>-----</td>
#       <td>0.147208</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.606316</td>
#       <td>dd</td>
#       <td>#SomeErrorVal</td>
#       <td>0.631835</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.824111</td>
#       <td>0.405234</td>
#       <td>0.407348</td>
#       <td>0.562546</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.917584</td>
#       <td>0.0878392</td>
#       <td>0.0882069</td>
#       <td>0.727976</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.272932</td>
#       <td>0.500158</td>
#       <td>NaN</td>
#       <td>0.147208</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.606316</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.631835</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.824111</td>
#       <td>0.405234</td>
#       <td>0.407348</td>
#       <td>0.562546</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Find NaN values from DataFrame

# %%
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])
df.iloc[2,1] = np.nan
df.iloc[0,0] = np.nan

# Calculate number of NaNs in column
print('Column ' + 'ee' + ' has {} NaNs'.format(pd.isnull(df['ee']).sum()))

df2 = df[df.isnull().any(axis=1)].copy()

display_side_by_side(df, df2)
# Out:
# Column ee has 1 NaNs
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>NaN</td>
#       <td>0.203049</td>
#       <td>0.389626</td>
#       <td>0.142566</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.828209</td>
#       <td>0.327358</td>
#       <td>0.726604</td>
#       <td>0.035119</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.861065</td>
#       <td>NaN</td>
#       <td>0.953240</td>
#       <td>0.469363</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.564079</td>
#       <td>0.944134</td>
#       <td>0.918997</td>
#       <td>0.107314</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>NaN</td>
#       <td>0.203049</td>
#       <td>0.389626</td>
#       <td>0.142566</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.861065</td>
#       <td>NaN</td>
#       <td>0.953240</td>
#       <td>0.469363</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Clean NaN values

# %%
df = pd.DataFrame(np.random.rand(4,4), columns = ['ff', 'ee', 'tt', 'uuu'], index = ['first','second','third','fourth'])
df.iloc[2,1] = np.nan
df.iloc[1,3] = np.nan
df.iloc[0,0] = np.nan
df2 = df.copy()
df3 = df.copy()

# Fill NaN by mean of the column
df2['ee'].fillna(df['ee'].mean(), inplace = True)

# Fill using value from previuous row
df2['uuu'].fillna(method='bfill', inplace = True)

# Fill using value from next row
df2['ff'].fillna(method='bfill', inplace = True)

# Fill multiple columns by some scalar value
df3[['ee','uuu', 'ff']] = df3[['ee','uuu', 'ff']].fillna(0)

display_side_by_side(df,df2,df3)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>NaN</td>
#       <td>0.093964</td>
#       <td>0.828949</td>
#       <td>0.446109</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.802137</td>
#       <td>0.675975</td>
#       <td>0.333764</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.158932</td>
#       <td>NaN</td>
#       <td>0.101848</td>
#       <td>0.616540</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.359729</td>
#       <td>0.584612</td>
#       <td>0.753306</td>
#       <td>0.383791</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.802137</td>
#       <td>0.093964</td>
#       <td>0.828949</td>
#       <td>0.446109</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.802137</td>
#       <td>0.675975</td>
#       <td>0.333764</td>
#       <td>0.616540</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.158932</td>
#       <td>0.451517</td>
#       <td>0.101848</td>
#       <td>0.616540</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.359729</td>
#       <td>0.584612</td>
#       <td>0.753306</td>
#       <td>0.383791</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ff</th>
#       <th>ee</th>
#       <th>tt</th>
#       <th>uuu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>first</th>
#       <td>0.000000</td>
#       <td>0.093964</td>
#       <td>0.828949</td>
#       <td>0.446109</td>
#     </tr>
#     <tr>
#       <th>second</th>
#       <td>0.802137</td>
#       <td>0.675975</td>
#       <td>0.333764</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>third</th>
#       <td>0.158932</td>
#       <td>0.000000</td>
#       <td>0.101848</td>
#       <td>0.616540</td>
#     </tr>
#     <tr>
#       <th>fourth</th>
#       <td>0.359729</td>
#       <td>0.584612</td>
#       <td>0.753306</td>
#       <td>0.383791</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Drop rows/columns with NaN values

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1],
                    [np.nan, np.nan, np.nan, 5]],
                   columns=list('ABCD'))

# Drop rows (axis = 0)/ columns (axis = 1) where all elements are NaN
df2 = df.dropna(axis = 1, how = 'all').copy()

# Drop rows (axis = 0)/ columns (axis = 1) where any element is NaN
df3 = df.dropna(axis = 1, how = 'any').copy()

# Keep rows (axis = 0)/ columns (axis = 1) which have at least thresh non-NaN values
df4 = df.dropna(axis = 1, thresh = 2).copy()

display_side_by_side(df, df2, df3, df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>2.0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>B</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Find nonnumeric values from string column

# %%
data = {'ID': [1, 2, 3], 'Names': ['Kate', 'John', 'Max'], 'Values': ['3', '4g', '8']}
df = pd.DataFrame(data=data, columns = ['ID', 'Names', 'Values'])
df2 = df[pd.to_numeric(df['Values'], errors='coerce').isnull()].copy()
display(df2)
# Out:
#    ID Names Values
# 1   2  John     4g

# %% [markdown]
# # Working with time and dates

# %% [markdown]
# ## Time and date data types

# %% [markdown]
# Pandas use 4 types of time functionalities
# <ol>
#   <li>Timestamp: a point in time</li>
#   <li>Period: period spanning over time range</li>
#   <li>DatetimeIndex</li>
#   <li>PeriodIndex</li>
# </ol>
#
# <b> It is recommended to use yyyy-mm-dd convention for dates!</b> This avoids the danger of misinterpreting months vs. days.

# %%
# Both of these create a TimeStamp, but only latter accepts frontward European convention!
display(pd.Timestamp('2008-12-10'))
display(pd.to_datetime('10-12-2008', dayfirst = True, format = '%d-%m-%Y')) # only to_datime has dayfirst option!
# Out:
# Timestamp('2008-12-10 00:00:00')
# Timestamp('2008-12-10 00:00:00')

# %%
# Examples of periods
display(pd.Period('2013'))
display(pd.Period('2017Q1'))
display(pd.Period('05/2017'))
display(pd.Period('2017-12-10'))
# Out:
# Period('2013', 'A-DEC')
# Period('2017Q1', 'Q-DEC')
# Period('2017-05', 'M')
# Period('2017-12-10', 'D')

# %%
# TimeStamp and Period indices in DataFrames
df1 = pd.DataFrame(np.arange(3), [pd.Timestamp('2008-12-10'), pd.Timestamp('2008-12-11'), pd.Timestamp('2008-12-12')])
df2 = pd.DataFrame(np.arange(3), [pd.Period('2008-12-10'), pd.Period('2008-12-11'), pd.Period('2008-12-12')])
df3 = pd.DataFrame(np.arange(3), [pd.Period('2008Q2'), pd.Period('2008Q3'), pd.Period('2008Q4')])
df4 = pd.DataFrame(np.arange(4), pd.date_range('2016-10-01', periods=4, freq='1D'))
df5 = pd.DataFrame(np.arange(4), pd.date_range('2016-10-01', periods=4, freq='3W-SUN')) #SUN specifies we want only sundays

display_side_by_side(df1,df2,df3,df4,df5)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2008-12-10</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2008-12-11</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2008-12-12</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2008-12-10</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2008-12-11</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2008-12-12</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2008Q2</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2008Q3</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2008Q4</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2016-10-01</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2016-10-02</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2016-10-03</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2016-10-04</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2016-10-02</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2016-10-23</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2016-11-13</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2016-12-04</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
# Convert column into a PeriodIndex
df = pd.DataFrame({'Quarter': ['2008-01-01','2008-04-01','2008-07-01'], 'Values': [5,3,8]})
df2 = pd.DataFrame()
df2['Values'] = df['Values']
df2.index = pd.PeriodIndex(df['Quarter'], freq = '1Q')
df2.index.name = None

df3 = pd.DataFrame({'Year': ['2008', '2009', '2010'], 'Values': [5,3,8]})
df4 = pd.DataFrame()
df4['Values'] = df3['Values']
df4.index = pd.PeriodIndex(df3['Year'], freq = '1A')
df4.index.name = None

display_side_by_side(df,df2,df3,df4)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Quarter</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2008-01-01</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2008-04-01</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2008-07-01</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2008Q1</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2008Q2</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2008Q3</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#       <th>Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>2008</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>2009</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>2010</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2008</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2009</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2010</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %%
#TimeDelta is the difference between two TimeStamps
display(pd.Timestamp('2008-12-10') - pd.Timestamp('2009-04-10'))
# Out:
# Timedelta('-121 days +00:00:00')

# %% [markdown]
# ## Harmonize dates in data frame

# %%
'''
Top 2 answers here: https://stackoverflow.com/questions/23581128/how-to-format-date-string-via-multiple-formats-in-python
See also http://strftime.org/
'''
import dateutil.parser
from datetime import datetime

data = {'value': [1, 2, 3, 5, 8], 'dates': ['03/25/93', '04-12-2012', 'Feb. 17, 2005', '6/2006', '2010']}
df1 = pd.DataFrame(data=data)
df2 = df1.copy()

# User-defined function for version 2
def try_parsing_date(text):
    for fmt in ('%Y-%m-%d','%m/%d/%y','%m/%d/%Y','%m-%d-%y','%m-%d-%Y',
                '%d %b %Y','%d %B %Y','%B %d, %Y','%b %d, %Y',
                '%B. %d, %Y','%b %d %Y','%b. %d, %Y','%B %d %Y',
                '%B %Y','%B, %Y','%b, %Y','%b %Y','%m/%Y','%Y'):
        try:
            return datetime.strptime(text, fmt)
        except ValueError:
            pass
    print(text)
    raise ValueError('no valid date format found')

# This is version1 relying on dateutil.parser
# It is pretty good in general case, but might fail on
# very custom dates. Further, fallback treatment for eg. 
# missing days or months is werid; it takes current day/month!
datetimes1 = list()
for index, row in df2.iterrows():
    datetimes1.append(dateutil.parser.parse(row['dates']))
df1['dates_dt'] = datetimes1

# Second version with user-defined function relies on
# datetime.strptime. It is more detailed as different date
# formats can be specified separately. Further, fallback treatment
# of missgin days/months is more convenient
datetimes2 = list()
for index, row in df2.iterrows():
    datetimes2.append(try_parsing_date(row['dates']))
df2['dates_dt'] = datetimes2    


display_side_by_side(df1,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dates</th>
#       <th>value</th>
#       <th>dates_dt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>03/25/93</td>
#       <td>1</td>
#       <td>1993-03-25</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>04-12-2012</td>
#       <td>2</td>
#       <td>2012-04-12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Feb. 17, 2005</td>
#       <td>3</td>
#       <td>2005-02-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6/2006</td>
#       <td>5</td>
#       <td>2006-06-12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2010</td>
#       <td>8</td>
#       <td>2010-08-12</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dates</th>
#       <th>value</th>
#       <th>dates_dt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>03/25/93</td>
#       <td>1</td>
#       <td>1993-03-25</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>04-12-2012</td>
#       <td>2</td>
#       <td>2012-04-12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Feb. 17, 2005</td>
#       <td>3</td>
#       <td>2005-02-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6/2006</td>
#       <td>5</td>
#       <td>2006-06-01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2010</td>
#       <td>8</td>
#       <td>2010-01-01</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# ## Time series tricks

# %% [markdown]
# ### Basic operations

# %%
# Start indexing from Thursday 2009-10-01
df = pd.DataFrame({'Values': np.random.randn(8).cumsum()}
                  ,index = pd.date_range('2009-10-01'
                  , periods=8, freq='1W-THU'))

# Nth differences
df2 = df.diff(2).copy()

# Downsample to monthly by mean (or sum, min, max)
df3 = df.resample('M').mean().copy()

# Upsample, and upfill
df3b = df.resample('D').ffill().copy()

# Upsample, use interpolation
df3c = df.resample('D').interpolate('linear').copy()

# Slice DataFrame to only include observations between some range
df4 = df['2009-10-09':'2009-11-07'].copy()

# Change frequency
df5 = df.asfreq('2W-THU').copy()

display_side_by_side(df,df2,df3,df3b.head(10),df3c.head(10),df4,df5)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-08</th>
#       <td>-0.380112</td>
#     </tr>
#     <tr>
#       <th>2009-10-15</th>
#       <td>-1.423378</td>
#     </tr>
#     <tr>
#       <th>2009-10-22</th>
#       <td>0.047529</td>
#     </tr>
#     <tr>
#       <th>2009-10-29</th>
#       <td>0.998034</td>
#     </tr>
#     <tr>
#       <th>2009-11-05</th>
#       <td>0.231819</td>
#     </tr>
#     <tr>
#       <th>2009-11-12</th>
#       <td>1.007777</td>
#     </tr>
#     <tr>
#       <th>2009-11-19</th>
#       <td>-0.701414</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2009-10-08</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2009-10-15</th>
#       <td>-0.301327</td>
#     </tr>
#     <tr>
#       <th>2009-10-22</th>
#       <td>0.427641</td>
#     </tr>
#     <tr>
#       <th>2009-10-29</th>
#       <td>2.421412</td>
#     </tr>
#     <tr>
#       <th>2009-11-05</th>
#       <td>0.184290</td>
#     </tr>
#     <tr>
#       <th>2009-11-12</th>
#       <td>0.009743</td>
#     </tr>
#     <tr>
#       <th>2009-11-19</th>
#       <td>-0.933233</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-31</th>
#       <td>-0.375995</td>
#     </tr>
#     <tr>
#       <th>2009-11-30</th>
#       <td>0.179394</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-02</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-03</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-04</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-05</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-06</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-07</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-08</th>
#       <td>-0.380112</td>
#     </tr>
#     <tr>
#       <th>2009-10-09</th>
#       <td>-0.380112</td>
#     </tr>
#     <tr>
#       <th>2009-10-10</th>
#       <td>-0.380112</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-02</th>
#       <td>-1.016060</td>
#     </tr>
#     <tr>
#       <th>2009-10-03</th>
#       <td>-0.910068</td>
#     </tr>
#     <tr>
#       <th>2009-10-04</th>
#       <td>-0.804077</td>
#     </tr>
#     <tr>
#       <th>2009-10-05</th>
#       <td>-0.698086</td>
#     </tr>
#     <tr>
#       <th>2009-10-06</th>
#       <td>-0.592094</td>
#     </tr>
#     <tr>
#       <th>2009-10-07</th>
#       <td>-0.486103</td>
#     </tr>
#     <tr>
#       <th>2009-10-08</th>
#       <td>-0.380112</td>
#     </tr>
#     <tr>
#       <th>2009-10-09</th>
#       <td>-0.529150</td>
#     </tr>
#     <tr>
#       <th>2009-10-10</th>
#       <td>-0.678188</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-15</th>
#       <td>-1.423378</td>
#     </tr>
#     <tr>
#       <th>2009-10-22</th>
#       <td>0.047529</td>
#     </tr>
#     <tr>
#       <th>2009-10-29</th>
#       <td>0.998034</td>
#     </tr>
#     <tr>
#       <th>2009-11-05</th>
#       <td>0.231819</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>-1.122051</td>
#     </tr>
#     <tr>
#       <th>2009-10-15</th>
#       <td>-1.423378</td>
#     </tr>
#     <tr>
#       <th>2009-10-29</th>
#       <td>0.998034</td>
#     </tr>
#     <tr>
#       <th>2009-11-12</th>
#       <td>1.007777</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# <h3>Get mean value per day over multiple years</h3>

# %%
startdate = datetime.datetime(2004, 1, 1)
enddate = datetime.datetime(2008, 1, 1)
days = (enddate + datetime.timedelta(days = 1) - startdate).days
data = np.random.random(days)
dates = [startdate + datetime.timedelta(days=x) for x in range(0, days)]

ts = pd.DataFrame(data, dates, columns = ['values'])
ts.index.names = ['Day']

# Average at each day over multiple years
day_averages = ts.groupby([ts.index.month, ts.index.day]).mean()
day_averages.index.names = ['Month', 'Day']
day_averages.columns = ['avg_values']

display_side_by_side(ts.head(10), pd.DataFrame(day_averages).head(10))
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>values</th>
#     </tr>
#     <tr>
#       <th>Day</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2004-01-01</th>
#       <td>0.714957</td>
#     </tr>
#     <tr>
#       <th>2004-01-02</th>
#       <td>0.571560</td>
#     </tr>
#     <tr>
#       <th>2004-01-03</th>
#       <td>0.091580</td>
#     </tr>
#     <tr>
#       <th>2004-01-04</th>
#       <td>0.363773</td>
#     </tr>
#     <tr>
#       <th>2004-01-05</th>
#       <td>0.619939</td>
#     </tr>
#     <tr>
#       <th>2004-01-06</th>
#       <td>0.793272</td>
#     </tr>
#     <tr>
#       <th>2004-01-07</th>
#       <td>0.797984</td>
#     </tr>
#     <tr>
#       <th>2004-01-08</th>
#       <td>0.342760</td>
#     </tr>
#     <tr>
#       <th>2004-01-09</th>
#       <td>0.686082</td>
#     </tr>
#     <tr>
#       <th>2004-01-10</th>
#       <td>0.668848</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>avg_values</th>
#     </tr>
#     <tr>
#       <th>Month</th>
#       <th>Day</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="10" valign="top">1</th>
#       <th>1</th>
#       <td>0.661626</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.532938</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.278649</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.383683</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.282340</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.473892</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.556195</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.754630</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.363717</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.346607</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">

# %% [markdown]
# # Uncategorized

# %% [markdown]
# ## Re-index columns to start e.g from 100

# %%
df = pd.DataFrame({'Values': np.random.randn(8).cumsum()}
                  ,index = pd.date_range('2009-10-01'
                  , periods=8, freq='1W-THU'))
df2 = df.copy()
df2['type'] = 't1'
for col in df2.columns.values[:-1]:
    gg = df2.groupby('type')[col].apply(lambda x: x.div(x.iloc[0]).subtract(1))
    df2[col] = (1 + gg) * 100
df2.drop(['type'], axis = 1, inplace = True)

display_side_by_side(df,df2)
# Out:
# <table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>0.290385</td>
#     </tr>
#     <tr>
#       <th>2009-10-08</th>
#       <td>-0.227807</td>
#     </tr>
#     <tr>
#       <th>2009-10-15</th>
#       <td>-0.122698</td>
#     </tr>
#     <tr>
#       <th>2009-10-22</th>
#       <td>-0.509068</td>
#     </tr>
#     <tr>
#       <th>2009-10-29</th>
#       <td>-0.007475</td>
#     </tr>
#     <tr>
#       <th>2009-11-05</th>
#       <td>0.876634</td>
#     </tr>
#     <tr>
#       <th>2009-11-12</th>
#       <td>1.391419</td>
#     </tr>
#     <tr>
#       <th>2009-11-19</th>
#       <td>2.821744</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px"><table style="display:inline; border:0px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2009-10-01</th>
#       <td>100.000000</td>
#     </tr>
#     <tr>
#       <th>2009-10-08</th>
#       <td>-78.450058</td>
#     </tr>
#     <tr>
#       <th>2009-10-15</th>
#       <td>-42.253688</td>
#     </tr>
#     <tr>
#       <th>2009-10-22</th>
#       <td>-175.308105</td>
#     </tr>
#     <tr>
#       <th>2009-10-29</th>
#       <td>-2.574245</td>
#     </tr>
#     <tr>
#       <th>2009-11-05</th>
#       <td>301.886828</td>
#     </tr>
#     <tr>
#       <th>2009-11-12</th>
#       <td>479.163695</td>
#     </tr>
#     <tr>
#       <th>2009-11-19</th>
#       <td>971.725625</td>
#     </tr>
#   </tbody>
# </table style="display:inline; border:0px">
